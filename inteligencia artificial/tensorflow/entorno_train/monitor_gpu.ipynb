# %%
# !nvidia-smi
# Out:
# Tue Dec 12 11:55:47 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.29.06              Driver Version: 545.29.06    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3070        Off | 00000000:01:00.0  On |                  N/A |
# | 64%   81C    P2             205W / 220W |   5405MiB /  8192MiB |     79%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import time
for i in range(150):
    time.sleep(5)
    # !gpustat
# Out:
# b1c0007c9843                Tue Dec 12 12:28:56 2023  545.29.06
# [0] NVIDIA GeForce RTX 3070 | 82°C,  92 % |  5387 /  8192 MB |
# b1c0007c9843                Tue Dec 12 12:29:02 2023  545.29.06
# [0] NVIDIA GeForce RTX 3070 | 82°C,  88 % |  5387 /  8192 MB |
# b1c0007c9843                Tue Dec 12 12:29:08 2023  545.29.06
# [0] NVIDIA GeForce RTX 3070 | 82°C,  95 % |  5387 /  8192 MB |
# b1c0007c9843                Tue Dec 12 12:29:15 2023  545.29.06
# [0] NVIDIA GeForce RTX 3070 | 82°C,  90 % |  5387 /  8192 MB |
# b1c0007c9843                Tue Dec 12 12:29:20 2023  545.29.06
# [0] NVIDIA GeForce RTX 3070 | 81°C,  96 % |  5387 /  8192 MB |
# b1c0007c9843                Tue Dec 12 12:29:26 2023  545.29.06
# [0] NVIDIA GeForce RTX 3070 | 78°C,  66 % |  5387 /  8192 MB |
# b1c0007c9843                Tue Dec 12 12:29:33 2023  545.29.06
# [0] NVIDIA GeForce RTX 3070 | 75°C,  83 % |  5387 /  8192 MB |
# b1c0007c9843                Tue Dec 12 12:29:39 2023  545.29.06
# ...
